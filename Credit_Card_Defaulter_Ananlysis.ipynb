# %% [raw]
# The primary libraries of python that we'll be using are:
#
#
# •	NumPy: Provides a fast-numerical array structure and helper functions.
#
# •	pandas: Provides a Data Frame structure to store data in memory and work with it easily and efficiently.
#
# •	matplotlib: Basic plotting library in Python; most other Python plotting libraries are built on top of it.

# %% [raw]
#  Firstly we will see each feature meaning following are the features
#
# 1.ID: ID of each client
# 2.LIMIT_BAL: Amount of given credit in NT dollars (includes individual and family/supplementary credit
# 3.SEX: Gender (1=male, 2=female)
# 4.EDUCATION: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)
# 5.MARRIAGE: Marital status (1=married, 2=single, 3=others)
# 6.AGE: Age in years
# 7.PAY_0: Repayment status in September, 2005 (-1=pay duly, 1=payment delay for one month, 2=payment delay for two
# 8.months, … 8=payment delay for eight months, 9=payment delay for nine months and above)
# 9.PAY_2: Repayment status in August, 2005 (scale same as above)
# 10.PAY_3: Repayment status in July, 2005 (scale same as above)
# 11.PAY_4: Repayment status in June, 2005 (scale same as above)
# 12.PAY_5: Repayment status in May, 2005 (scale same as above)
# 13.PAY_6: Repayment status in April, 2005 (scale same as above)
# 14.BILL_AMT1: Amount of bill statement in September, 2005 (NT dollar)
# 15.BILL_AMT2: Amount of bill statement in August, 2005 (NT dollar)
# 16.BILL_AMT3: Amount of bill statement in July, 2005 (NT dollar)
# 17.BILL_AMT4: Amount of bill statement in June, 2005 (NT dollar)
# 18.BILL_AMT5: Amount of bill statement in May, 2005 (NT dollar)
# 19.BILL_AMT6: Amount of bill statement in April, 2005 (NT dollar)
# 20.PAY_AMT1: Amount of previous payment in September, 2005 (NT dollar)
# 21.PAY_AMT2: Amount of previous payment in August, 2005 (NT dollar)
# 22.PAY_AMT3: Amount of previous payment in July, 2005 (NT dollar)
# 23.PAY_AMT4: Amount of previous payment in June, 2005 (NT dollar)
# 24.PAY_AMT5: Amount of previous payment in May, 2005 (NT dollar)
# 25.PAY_AMT6: Amount of previous payment in April, 2005 (NT dollar)
# 26.default.payment.next.month: Default payment (1=yes, 0=no)
# from above data biling amount for 6 months and amount which is payed by person given by pay_amount for 6 months.

# %%
#Importing the libraries 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px
from pandas import set_option
plt.style.use('ggplot') # nice plots

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-223b3ece-6559-4196-b9bf-57da42f18f1b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-223b3ece-6559-4196-b9bf-57da42f18f1b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving default_of_credit_card_clients.csv.zip to default_of_credit_card_clients.csv.zip

# %%
df = pd.read_csv('default_of_credit_card_clients.csv.zip')

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# std        9.217904      1.123802      1.197186      1.196868      1.169139
# min       21.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       28.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%       34.000000      0.000000      0.000000      0.000000      0.000000
# 75%       41.000000      0.000000      0.000000      0.000000      0.000000
# max       79.000000      8.000000      8.000000      8.000000      8.000000
#
#        ...      BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1  \
# count  ...   30000.000000   30000.000000   30000.000000   30000.000000
# mean   ...   43262.948967   40311.400967   38871.760400    5663.580500
# std    ...   64332.856134   60797.155770   59554.107537   16563.280354
# min    ... -170000.000000  -81334.000000 -339603.000000       0.000000
# 25%    ...    2326.750000    1763.000000    1256.000000    1000.000000
# 50%    ...   19052.000000   18104.500000   17071.000000    2100.000000
# 75%    ...   54506.000000   50190.500000   49198.250000    5006.000000
# max    ...  891586.000000  927171.000000  961664.000000  873552.000000
#
#            PAY_AMT2      PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count  3.000000e+04   30000.00000   30000.000000   30000.000000
# mean   5.921163e+03    5225.68150    4826.076867    4799.387633
# std    2.304087e+04   17606.96147   15666.159744   15278.305679
# min    0.000000e+00       0.00000       0.000000       0.000000
# 25%    8.330000e+02     390.00000     296.000000     252.500000
# 50%    2.009000e+03    1800.00000    1500.000000    1500.000000
# 75%    5.000000e+03    4505.00000    4013.250000    4031.500000
# max    1.684259e+06  896040.00000  621000.000000  426529.000000
#
#             PAY_AMT6  default payment next month
# count   30000.000000                30000.000000
# mean     5215.502567                    0.221200
# std     17777.465775                    0.415062
# min         0.000000                    0.000000
# 25%       117.750000                    0.000000
# 50%      1500.000000                    0.000000
# 75%      4000.000000                    0.000000
# max    528666.000000                    1.000000
#
# [8 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
#  13  BILL_AMT2                   30000 non-null  int64
#  14  BILL_AMT3                   30000 non-null  int64
#  15  BILL_AMT4                   30000 non-null  int64
#  16  BILL_AMT5                   30000 non-null  int64
#  17  BILL_AMT6                   30000 non-null  int64
#  18  PAY_AMT1                    30000 non-null  int64
#  19  PAY_AMT2                    30000 non-null  int64
#  20  PAY_AMT3                    30000 non-null  int64
#  21  PAY_AMT4                    30000 non-null  int64
#  22  PAY_AMT5                    30000 non-null  int64
#  23  PAY_AMT6                    30000 non-null  int64
#  24  default payment next month  30000 non-null  int64
# dtypes: int64(25)
# memory usage: 5.7 MB

# %% [markdown]
# Changing ‘PAY_0 to PAY_1’ to keep in the same pattern as the other ‘September’ features . Changing Default's name to make it shorter.

# %%
df.rename(columns = {'PAY_0':'PAY_1', 'default payment next month':'def_pay'}, inplace = True)
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0         -1  ...          0          0          0         0       689
# 1          0  ...       3272       3455       3261         0      1000
# 2          0  ...      14331      14948      15549      1518      1500
# 3          0  ...      28314      28959      29547      2000      2019
# 4          0  ...      20940      19146      19131      2000     36681
# ...      ...  ...        ...        ...        ...       ...       ...
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  def_pay
# 0             0         0         0         0        1
# 1          1000      1000         0      2000        1
# 2          1000      1000      1000      5000        0
# 3          1200      1100      1069      1000        0
# 4         10000      9000       689       679        0
# ...         ...       ...       ...       ...      ...
# 29995      5003      3047      5000      1000        0
# 29996      8998       129         0         0        0
# 29997     22000      4200      2000      3100        1
# 29998      1178      1926     52964      1804        1
# 29999      1430      1000      1000      1000        1
#
# [30000 rows x 25 columns]

# %%
# Dealing with catagorical variable 
df['EDUCATION'].value_counts()
# Out:
# 2    14030
# 1    10585
# 3     4917
# 5      280
# 4      123
# 6       51
# 0       14
# Name: EDUCATION, dtype: int64

# %%
# Unknown Varable 
df.loc[:,'EDUCATION'] = df.loc[:,'EDUCATION'].replace(0,5)

df.loc[:,'EDUCATION'] = df.loc[:,'EDUCATION'].replace(6,5)

# %%
# same analysis for all 
df['MARRIAGE'].value_counts()
# Out:
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: MARRIAGE, dtype: int64

# %%
df.loc[:,'MARRIAGE'] = df.loc[:,'MARRIAGE'].replace(0,3)

# %%
df['SEX'].value_counts()
# Out:
# 2    18112
# 1    11888
# Name: SEX, dtype: int64

# %%
"""
Outstading Amount
Card issuers assign specific credit limits (spending limits) on your cards.
Your outstanding balance helps determine how much credit (money left to spend) you have available. 
To find out how much you have left, simply subtract your outstanding balance from your credit limit.
In simple words Money utilised 
""" 
"""
Outstanding Amount for Bank will be Sum of limit Balance 
"""
df['bill_total'] =df['BILL_AMT1']+df['BILL_AMT2']+df['BILL_AMT3']+df['BILL_AMT4']+df['BILL_AMT5']+df['BILL_AMT6']
df['pay_amt_total'] =df['PAY_AMT1']+df['PAY_AMT2']+df['PAY_AMT3']+df['PAY_AMT4']+df['PAY_AMT5']+df['PAY_AMT6']
df['remaining_pay_balance'] =df['bill_total']-df['pay_amt_total']

# %% [markdown]
# ### Exploratory Data Analysis (EDA)
#
# Mapping the target: categorizing
# From this sample of 30,000 credit card holders, there were 6,636 default credit cards; that is, the proportion of default in the data is 22,1%

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df['def_pay'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[1].set_title('COUNT OF CREDIT CARDS')
ax[0].set_title('COUNT OF CREDIT CARDS')
ax[0].set_ylabel('')
sns.countplot('def_pay',data=df,ax=ax[1])
plt.annotate('Non-default: {}'.format(0), xy=(-0.3, 15000), xytext=(-0.3, 3000), size=12)
plt.annotate('Default: {}'.format(1), xy=(0.7, 15000), xytext=(0.7, 3000), size=12)
ax[1].set_title('COUNT OF CREDIT CARDS')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
set_option('display.width', 100)
set_option('precision', 2)

print("SUMMARY STATISTICS OF NUMERIC COLUMNS")
print()
print(df.describe().T)
df.describe().T.plot()
# Out:
# SUMMARY STATISTICS OF NUMERIC COLUMNS
#
#                          count       mean        std       min       25%       50%        75%  \
# ID                     30000.0   15000.50    8660.40  1.00e+00   7500.75   15000.5   22500.25
# LIMIT_BAL              30000.0  167484.32  129747.66  1.00e+04  50000.00  140000.0  240000.00
# SEX                    30000.0       1.60       0.49  1.00e+00      1.00       2.0       2.00
# EDUCATION              30000.0       1.85       0.78  1.00e+00      1.00       2.0       2.00
# MARRIAGE               30000.0       1.56       0.52  1.00e+00      1.00       2.0       2.00
# AGE                    30000.0      35.49       9.22  2.10e+01     28.00      34.0      41.00
# PAY_1                  30000.0      -0.02       1.12 -2.00e+00     -1.00       0.0       0.00
# PAY_2                  30000.0      -0.13       1.20 -2.00e+00     -1.00       0.0       0.00
# PAY_3                  30000.0      -0.17       1.20 -2.00e+00     -1.00       0.0       0.00
# PAY_4                  30000.0      -0.22       1.17 -2.00e+00     -1.00       0.0       0.00
# PAY_5                  30000.0      -0.27       1.13 -2.00e+00     -1.00       0.0       0.00
# PAY_6                  30000.0      -0.29       1.15 -2.00e+00     -1.00       0.0       0.00
# BILL_AMT1              30000.0   51223.33   73635.86 -1.66e+05   3558.75   22381.5   67091.00
# BILL_AMT2              30000.0   49179.08   71173.77 -6.98e+04   2984.75   21200.0   64006.25
# BILL_AMT3              30000.0   47013.15   69349.39 -1.57e+05   2666.25   20088.5   60164.75
# BILL_AMT4              30000.0   43262.95   64332.86 -1.70e+05   2326.75   19052.0   54506.00
# BILL_AMT5              30000.0   40311.40   60797.16 -8.13e+04   1763.00   18104.5   50190.50
# BILL_AMT6              30000.0   38871.76   59554.11 -3.40e+05   1256.00   17071.0   49198.25
# PAY_AMT1               30000.0    5663.58   16563.28  0.00e+00   1000.00    2100.0    5006.00
# PAY_AMT2               30000.0    5921.16   23040.87  0.00e+00    833.00    2009.0    5000.00
# PAY_AMT3               30000.0    5225.68   17606.96  0.00e+00    390.00    1800.0    4505.00
# PAY_AMT4               30000.0    4826.08   15666.16  0.00e+00    296.00    1500.0    4013.25
# PAY_AMT5               30000.0    4799.39   15278.31  0.00e+00    252.50    1500.0    4031.50
# PAY_AMT6               30000.0    5215.50   17777.47  0.00e+00    117.75    1500.0    4000.00
# def_pay                30000.0       0.22       0.42  0.00e+00      0.00       0.0       0.00
# bill_total             30000.0  269861.67  379564.33 -3.36e+05  28688.00  126311.0  342626.50
# pay_amt_total          30000.0   31651.39   60827.68  0.00e+00   6679.75   14383.0   33503.50
# remaining_pay_balance  30000.0  238210.28  363165.06 -2.67e+06   4520.75  101923.0  305717.75
#
#                             max
# ID                     3.00e+04
# LIMIT_BAL              1.00e+06
# SEX                    2.00e+00
# EDUCATION              5.00e+00
# MARRIAGE               3.00e+00
# AGE                    7.90e+01
# PAY_1                  8.00e+00
# PAY_2                  8.00e+00
# PAY_3                  8.00e+00
# PAY_4                  8.00e+00
# PAY_5                  8.00e+00
# PAY_6                  8.00e+00
# BILL_AMT1              9.65e+05
# BILL_AMT2              9.84e+05
# BILL_AMT3              1.66e+06
# BILL_AMT4              8.92e+05
# BILL_AMT5              9.27e+05
# BILL_AMT6              9.62e+05
# PAY_AMT1               8.74e+05
# PAY_AMT2               1.68e+06
# PAY_AMT3               8.96e+05
# PAY_AMT4               6.21e+05
# PAY_AMT5               4.27e+05
# PAY_AMT6               5.29e+05
# def_pay                1.00e+00
# bill_total             5.26e+06
# pay_amt_total          3.76e+06
# remaining_pay_balance  4.12e+06

# %% [raw]
# The average value for the amount of credit card limit is 167,484 NT dollars. The standard deviation is 129,747 NT dollars, ranging from 10,000 to 1M NT dollars.
# Education level is mostly graduate school (1) and university (2). Most of the clients are either marrined or single (less frequent the other status). Average age is 35.5 years, with a standard deviation of 9.2 years.

# %% [markdown]
# #### The negative values on BILL_AMTX also seemed odd, but it could simply mean that the customers paid more than their actual debts. A lower probability of default is expected for those customers.

# %% [markdown]
# ###### Outstanding Amount for Bank will be Sum of limit Balance

# %% [markdown]
# ### Amount of Given Credit (LIMIT_BAL)
# ### The trend on outstanding amount for the bank

# %%
plt.figure(figsize=(12,4))

sns.distplot(df['LIMIT_BAL'])
plt.ticklabel_format(style='plain', axis='x') #repressing scientific notation on x
plt.ylabel('')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12,4))

sns.distplot(df['bill_total'])
plt.ticklabel_format(style='plain', axis='x') #repressing scientific notation on x
plt.ylabel('')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
## The negative sign indicates an overpayment of the bill and you may be eligible for a refund.

# %%
x1 = list(df[df['def_pay'] == 1]['LIMIT_BAL'])
x2 = list(df[df['def_pay'] == 0]['LIMIT_BAL'])

plt.figure(figsize=(12,4))
sns.set_context('notebook', font_scale=1.2)

plt.hist([x1, x2], bins = 40)
plt.xlim([0,600000])
plt.legend(['Yes', 'No'], title = 'Default', loc='upper right', facecolor='white')
plt.xlabel('Limit Balance (NT dollar)')
plt.ylabel('Frequency')
plt.title('LIMIT BALANCE HISTOGRAM BY TYPE OF CREDIT CARD', SIZE=15)
plt.box(False)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
x1 = list(df[df['def_pay'] == 1]['bill_total'])
x2 = list(df[df['def_pay'] == 0]['bill_total'])

plt.figure(figsize=(12,4))
sns.set_context('notebook', font_scale=1.2)
#sns.set_color_codes("pastel")
plt.hist([x1, x2], bins = 40)
plt.xlim([-10000,600000])
plt.legend(['Yes', 'No'], title = 'Default', loc='upper right', facecolor='white')
plt.xlabel('Limit Balance (NT dollar)')
plt.ylabel('Frequency')
plt.title('BIll Amount HISTOGRAM BY TYPE OF CREDIT CARD', SIZE=15)
plt.box(False)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# There are 30,000 credit card clients.
#
# The average value for the amount of credit card limit is 167,484 NT dollars. The standard deviation is 129,747 NT dollars, ranging from 10,000 to 1M NT dollars
# As the value 0 for default payment means 'not default' and value 1 means 'default', the mean of 0.221 means that there are 22.1% of credit card contracts that will default next month (will verify this in the next sections of this analysis).

# %% [markdown]
# ### Number of customers with outstanding amount (in different outstanding amount buckets)

# %%
df['LimitBin'] = pd.cut(df['LIMIT_BAL'],[5000, 50000, 100000, 150000, 200000, 300000, 400000, 500000, 1100000])
print(df['LimitBin'].value_counts())
# Out:
# (5000, 50000]        7676
# (200000, 300000]     5059
# (50000, 100000]      4822
# (150000, 200000]     3978
# (100000, 150000]     3902
# (300000, 400000]     2759
# (400000, 500000]     1598
# (500000, 1100000]     206
# Name: LimitBin, dtype: int64

# %%
df['def_pay'].groupby(df['LimitBin']).value_counts(normalize = True)
# Out:
# LimitBin           def_pay
# (5000, 50000]      0          0.68
#                    1          0.32
# (50000, 100000]    0          0.74
#                    1          0.26
# (100000, 150000]   0          0.79
#                    1          0.21
# (150000, 200000]   0          0.82
#                    1          0.18
# (200000, 300000]   0          0.84
#                    1          0.16
# (300000, 400000]   0          0.86
#                    1          0.14
# (400000, 500000]   0          0.88
#                    1          0.12
# (500000, 1100000]  0          0.89
#                    1          0.11
# Name: def_pay, dtype: float64

# %%
plt.figure(figsize=(14,4))

df['LimitBin'] = df['LimitBin'].astype('str')
LimitBin_order = ['(5000, 50000]', '(50000, 100000]', '(100000, 150000]', '(150000, 200000]',
                '(200000, 300000]', '(300000, 400000]', '(400000, 500000]', '(500000, 1100000]']

ax = sns.countplot(data = df, x = 'LimitBin', hue="def_pay", order = LimitBin_order)

plt.xlabel("Amount of Given Credit", fontsize= 12)
plt.ylabel("Number of customers", fontsize= 12)
plt.ylim(0,8000)
ax.tick_params(axis="x", labelsize= 10)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.075, p.get_height()+300))

plt.show()

# %%
plt.figure(figsize=(20,4))

ax = sns.barplot(x = "LimitBin", y = "def_pay", data = df, palette = 'flare', ci = None, order = LimitBin_order)

plt.xlabel("Amount of Given Credit", fontsize= 12)
plt.ylabel("% of Default", fontsize= 12)
plt.ylim(0,0.5)

for p in ax.patches:
    ax.annotate("%.2f" %(p.get_height()), (p.get_x()+0.25, p.get_height()+0.03),fontsize=13)

plt.show()

# %% [markdown]
# The analysis shows a a significant rate of default (over 30%) from customers with 50k or less of credit limit. We also can see that the higher the limit, the lower is the chance of defaulting.

# %%
df['LimitBin_A'] = pd.cut(df['bill_total'],[-336000,-150000,-10000, -5000,0,5000, 50000, 100000, 150000, 200000, 300000, 400000, 500000, 1100000])
print(df['LimitBin_A'].value_counts())
# Out:
# (5000, 50000]         6215
# (500000, 1100000]     3789
# (50000, 100000]       3631
# (200000, 300000]      3262
# (100000, 150000]      2955
# (150000, 200000]      2306
# (0, 5000]             2255
# (300000, 400000]      1757
# (400000, 500000]      1434
# (-5000, 0]            1009
# (-150000, -10000]       33
# (-10000, -5000]         27
# (-336000, -150000]       1
# Name: LimitBin_A, dtype: int64

# %%
df['def_pay'].groupby(df['LimitBin_A']).value_counts(normalize = True)
# Out:
# LimitBin_A          def_pay
# (-336000, -150000]  1          1.00
# (-150000, -10000]   0          0.73
#                     1          0.27
# (-10000, -5000]     0          0.81
#                     1          0.19
# (-5000, 0]          0          0.65
#                     1          0.35
# (0, 5000]           0          0.74
#                     1          0.26
# (5000, 50000]       0          0.80
#                     1          0.20
# (50000, 100000]     0          0.79
#                     1          0.21
# (100000, 150000]    0          0.76
#                     1          0.24
# (150000, 200000]    0          0.75
#                     1          0.25
# (200000, 300000]    0          0.78
#                     1          0.22
# (300000, 400000]    0          0.80
#                     1          0.20
# (400000, 500000]    0          0.79
#                     1          0.21
# (500000, 1100000]   0          0.80
#                     1          0.20
# Name: def_pay, dtype: float64

# %%
plt.figure(figsize=(25,4))

df['LimitBin_A'] = df['LimitBin_A'].astype('str')
LimitBin_order = ['(-336000, -150000]','(-10000, -5000]','(-5000, 0]','(0, 5000]','(5000, 50000]', '(50000, 100000]', '(100000, 150000]', '(150000, 200000]',
                '(200000, 300000]', '(300000, 400000]', '(400000, 500000]', '(500000, 1100000]']

ax = sns.countplot(data = df, x = 'LimitBin_A', hue="def_pay",palette = 'rocket', order = LimitBin_order)

plt.xlabel("Amount of Given Credit", fontsize= 12)
plt.ylabel("Number of customers", fontsize= 12)
plt.ylim(0,6000)
ax.tick_params(axis="x", labelsize= 10)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.075, p.get_height()+300))

plt.show()

# %%
"""
We can see that that 
(-336000, -150000]
(-150000, -10000] are the outliers for the Total bill Amount 
"""
# Out:
# '\nWe can see that that \n(-336000, -150000]\n(-150000, -10000] are the outliers for the Total bill Amount \n'

# %%
### Analysis shows that Higher the total bill amount lower chances of being a defaulter

# %%
LimitBin_order = ['(-10000, -5000]','(-5000, 0]','(0, 5000]','(5000, 50000]', '(50000, 100000]', '(100000, 150000]', '(150000, 200000]',
                '(200000, 300000]', '(300000, 400000]', '(400000, 500000]', '(500000, 1100000]']

plt.figure(figsize=(30,10))

ax = sns.barplot(x = "LimitBin_A", y = "def_pay", data = df,palette = 'rocket',  ci = None, order = LimitBin_order)

plt.xlabel("Amount of Total Bill", fontsize= 12)
plt.ylabel("% of Default", fontsize= 12)
plt.ylim(0,1.5)

for p in ax.patches:
    ax.annotate("%.2f" %(p.get_height()), (p.get_x()+0.25, p.get_height()+0.03),fontsize=13)

plt.show()

# %% [markdown]
# As expected, those who have a negative bill statement have a lower chance of default than the rest. What stands out is that there is a little higher chance of default for those who didn't have a bill in the previous months.

# %%
plt.subplots(figsize=(20,5))

plt.subplot(221)
sns.distplot(df.AGE)


plt.subplot(222)
sns.distplot(df.remaining_pay_balance)



plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# To deep Dive into age analysis analysis for the bill amount and Limit amount 
df['AgeBin'] = pd.cut(df['AGE'],[20, 25, 30, 35, 40, 50, 60, 80])
print(df['AgeBin'].value_counts())
# Out:
# (25, 30]    7142
# (40, 50]    6005
# (30, 35]    5796
# (35, 40]    4917
# (20, 25]    3871
# (50, 60]    1997
# (60, 80]     272
# Name: AgeBin, dtype: int64

# %%
df['def_pay'].groupby(df['AgeBin']).value_counts(normalize = True)
# Out:
# AgeBin    def_pay
# (20, 25]  0          0.73
#           1          0.27
# (25, 30]  0          0.80
#           1          0.20
# (30, 35]  0          0.81
#           1          0.19
# (35, 40]  0          0.78
#           1          0.22
# (40, 50]  0          0.77
#           1          0.23
# (50, 60]  0          0.75
#           1          0.25
# (60, 80]  0          0.73
#           1          0.27
# Name: def_pay, dtype: float64

# %%
plt.figure(figsize=(12,4))

df['AgeBin'] = df['AgeBin'].astype('str')
AgeBin_order = ['(20, 25]', '(25, 30]', '(30, 35]', '(35, 40]', '(40, 50]', '(50, 60]', '(60, 80]']

ax = sns.countplot(data = df, x = 'AgeBin', hue="def_pay", palette = 'rocket', order = AgeBin_order)

plt.xlabel("Age Group", fontsize= 12)
plt.ylabel("# of Clients", fontsize= 12)
plt.ylim(0,8000)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.075, p.get_height()+300))

plt.show()

# %%
plt.figure(figsize=(12,4))

ax = sns.barplot(x = "AgeBin", y = "def_pay", data = df, palette = 'rocket', ci = None, order = AgeBin_order)

plt.xlabel("Age Group", fontsize= 12)
plt.ylabel("% of Default", fontsize= 12)
plt.ylim(0,0.5)

for p in ax.patches:
    ax.annotate("%.2f" %(p.get_height()), (p.get_x()+0.25, p.get_height()+0.03),fontsize=13)

plt.show()

# %% [markdown]
# As expected, the lowest chances of default are registered around 30-35 years old, while the highest occur at the extremes (20-25 and 60+).

# %%
plt.figure(figsize=(14,6))

sns.boxplot(x = "AgeBin", y = "LIMIT_BAL",hue= 'def_pay', data = df, order = AgeBin_order, showmeans=True, 
            meanprops={"markerfacecolor":"red",  "markeredgecolor":"black", "markersize":"10"})

plt.ticklabel_format(style='plain', axis='y') #repressing scientific notation    
plt.xlabel("Age Group", fontsize= 12)

plt.show()

# %%
plt.figure(figsize=(14,6))

sns.boxplot(x = "AgeBin", y = 'bill_total', hue= 'def_pay',data = df, order = AgeBin_order, showmeans=True, 
            meanprops={"markerfacecolor":"red",  "markeredgecolor":"black", "markersize":"10"})

plt.ticklabel_format(style='plain', axis='y') #repressing scientific notation    
plt.xlabel("Age Group", fontsize= 12)

plt.show()

# %%
df[["SEX", "def_pay"]].groupby(['SEX']).mean().sort_values(by='def_pay')
# Out:
#      def_pay
# SEX
# 2       0.21
# 1       0.24

# %% [markdown]
# Considering that about 22% of the customers will default, we see a couple of things:
#
# 1. there are significantly more women than men
# 2. men are most likely going to default the next month
#
#
# However, we don't have to jump to any conclusion just yet since there might be some lurking variable that justifies the data better (and, being SEX the first variable we look at, it is most likely the case). However, nice result and move on.

# %% [markdown]
# ###  Eduacational Analysis

# %%
# Defaulter with respect to the Education

plt.subplots(figsize=(10,5))

ax = sns.countplot(data = df, x = 'EDUCATION', hue="def_pay")

plt.xlabel("Education", fontsize= 12)
plt.ylabel("Numbers of Clients", fontsize= 12)
plt.ylim(0,12000)
plt.xticks([0,1,2,3,4],['Grad School','University','High School','Others','Unknown'], fontsize = 11)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.11, p.get_height()+500))


plt.show()

# %%
plt.subplots(figsize=(20,10))
plt.subplot(211)

sns.boxenplot(x = 'EDUCATION',y = 'bill_total',hue = 'MARRIAGE',data = df)
#sns.stripplot(x = 'EDUCATION',y = 'bill_total',data = df,linewidth = 1)

plt.subplots(figsize=(20,10))
plt.subplot(211)
sns.boxenplot(x = 'EDUCATION',y = 'LIMIT_BAL',hue = 'MARRIAGE',data = df)
#sns.stripplot(x = 'EDUCATION',y = 'LIMIT_BAL',data = df,linewidth = 1)

# %%
plt.figure(figsize=(12,4))

ax = sns.countplot(data = df, x = 'MARRIAGE', hue="def_pay", palette = 'rocket')

plt.xlabel("Marital Status", fontsize= 12)
plt.ylabel("# of Clients", fontsize= 12)
plt.ylim(0,15000)
plt.xticks([0,1,2],['Married', 'Single', 'Other'], fontsize = 11)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.12, p.get_height()+500))

plt.show()

# %%
plt.figure(figsize=(12,4))

ax = sns.barplot(x = "MARRIAGE", y = "def_pay", data = df, palette = 'rocket', ci = None)

plt.ylabel("% of Default", fontsize= 12)
plt.ylim(0,0.5)
plt.xticks([0,1,2],['Married', 'Single', 'Other'],fontsize = 11)

for p in ax.patches:
    ax.annotate("%.2f" %(p.get_height()), (p.get_x()+0.30, p.get_height()+0.03),fontsize=13)

plt.show()

# %% [raw]
# Here it seems that married people are most likely to default as well as the misterious category "Other" ( which is again numerically less relevant than the others)
#
# All considered, these three categories seem to affect the result we want to predict. Thus we keep them in mind for later.
#
# I try to explain these first results and, while I can imagine how marital status or education can determine the balance of your credit card, I can't find a way of explaining why the type of Sex can do that as well. This particular result could probably get more meaning when put in the context of the society this people belong to.

# %%
plt.subplots(figsize=(20,10))
plt.subplot(211)

ax = sns.barplot(x = "EDUCATION", y = "LIMIT_BAL", hue = "SEX", data = df, ci = None)

plt.ylabel("Limit balance ", fontsize= 12)
plt.xticks([0,1,2,3,4],['Grad School','University','High School','Others','Unknown'], fontsize = 11)


for p in ax.patches:
    ax.annotate("%.2f" %(p.get_height()), (p.get_x()+0.06, p.get_height()+0.03),fontsize=10)

plt.show()
plt.subplots(figsize=(20,10))
plt.subplot(211)

ax = sns.barplot(x = "EDUCATION", y = "bill_total", hue = "SEX", data = df, ci = None)

plt.ylabel("Bill Amount ", fontsize= 12)
plt.xticks([0,1,2,3,4],['Grad School','University','High School','Others','Unknown'], fontsize = 11)


for p in ax.patches:
    ax.annotate("%.2f" %(p.get_height()), (p.get_x()+0.06, p.get_height()+0.03),fontsize=10)

plt.show()

# %% [markdown]
# #### It seems that the higher is the education, the lower is the probability of defaulting the next month. Only exception is for the category labeled "Other" that, if we stick to the documentation, would be lower than high school. However, numerically they will not have much weight in the final result.

# %% [markdown]
# We saw earlier that the average given credit for women was slightly higher than for men. That still holds up for several combinations of categories, except among customers that:
#
# Have a grad school diploma;
# Are married;
# Are 50+ years old.

# %% [markdown]
# ### Analysis Based on the History of past payment.

# %%
plt.subplots(figsize=(20,10))

ind = sorted(df.PAY_1.unique())
pay_0 = (df.PAY_1[df['def_pay'] == 0].value_counts(normalize=True))
pay_1 = (df.PAY_1[df['def_pay'] == 1].value_counts(normalize=True))
total = pay_0.values+pay_1.values
pay_0_prop = np.true_divide(pay_0, total)*100
pay_1_prop = np.true_divide(pay_1, total)*100
plt.subplot(231)
plt.bar(ind, pay_1_prop, bottom=pay_0_prop, label='1')
plt.bar(ind, pay_0_prop, label='0')
plt.title("Repayment Status M-0- Coresponding to September", fontsize=15)

ind = sorted(df.PAY_2.unique())
pay_0 = (df.PAY_2[df['def_pay'] == 0].value_counts(normalize=True))
pay_1 = (df.PAY_2[df['def_pay'] == 1].value_counts(normalize=True))
for i in pay_0.index:
    if i not in pay_1.index:
        pay_1[i]=0
total = pay_0.values+pay_1.values
pay_0_prop = np.true_divide(pay_0, total)*100
pay_1_prop = np.true_divide(pay_1, total)*100
plt.subplot(232)
plt.bar(ind, pay_1_prop, bottom=pay_0_prop, label='1')
plt.bar(ind, pay_0_prop, label='0')
plt.title("Repayment Status M-1 Coresponding to Augest", fontsize=15)

ind = sorted(df.PAY_3.unique())
pay_0 = (df.PAY_3[df['def_pay'] == 0].value_counts(normalize=True))
pay_1 = (df.PAY_3[df['def_pay'] == 1].value_counts(normalize=True))
for i in pay_0.index:
    if i not in pay_1.index:
        pay_1[i]=0
total = pay_0.values+pay_1.values
pay_0_prop = np.true_divide(pay_0, total)*100
pay_1_prop = np.true_divide(pay_1, total)*100
plt.subplot(233)
plt.bar(ind, pay_1_prop, bottom=pay_0_prop, label='1')
plt.bar(ind, pay_0_prop, label='0')
plt.title("Repayment Status M-2 Coresponding to July", fontsize=15)

ind = sorted(df.PAY_4.unique())
pay_0 = (df.PAY_4[df['def_pay'] == 0].value_counts(normalize=True))
pay_1 = (df.PAY_4[df['def_pay'] == 1].value_counts(normalize=True))
for i in pay_0.index:
    if i not in pay_1.index:
        pay_1[i]=0
total = pay_0.values+pay_1.values
pay_0_prop = np.true_divide(pay_0, total)*100
pay_1_prop = np.true_divide(pay_1, total)*100
plt.subplot(234)
plt.bar(ind, pay_1_prop, bottom=pay_0_prop, label='1')
plt.bar(ind, pay_0_prop, label='0')
plt.title("Repayment Status M-3 Coresponding to June", fontsize=15)




ind = sorted(df.PAY_5.unique())
pay_0 = (df.PAY_5[df['def_pay'] == 0].value_counts(normalize=True))
pay_1 = (df.PAY_5[df['def_pay'] == 1].value_counts(normalize=True))
for i in pay_0.index:
    if i not in pay_1.index:
        pay_1[i]=0
for i in pay_1.index:
    if i not in pay_0.index:
        pay_0[i]=0
total = pay_0.values+pay_1.values
pay_0_prop = np.true_divide(pay_0, total)*100
pay_1_prop = np.true_divide(pay_1, total)*100
plt.subplot(235)
plt.bar(ind, pay_1_prop, bottom=pay_0_prop, label='1')
plt.bar(ind, pay_0_prop, label='0')
plt.title("Repayment Status M-5 Coresponding to May", fontsize=15)




ind = sorted(df.PAY_6.unique())
pay_0 = (df.PAY_6[df['def_pay'] == 0].value_counts(normalize=True))
pay_1 = (df.PAY_6[df['def_pay'] == 1].value_counts(normalize=True))
for i in pay_0.index:
    if i not in pay_1.index:
        pay_1[i]=0
for i in pay_1.index:
    if i not in pay_0.index:
        pay_0[i]=0
total = pay_0.values+pay_1.values
pay_0_prop = np.true_divide(pay_0, total)*100
pay_1_prop = np.true_divide(pay_1, total)*100
plt.subplot(236)
plt.bar(ind, pay_1_prop, bottom=pay_0_prop, label='1')
plt.bar(ind, pay_0_prop, label='0')
plt.title("Repayment Status M-6 Coresponding to April", fontsize=15)


plt.xticks(ind, fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc="upper right", fontsize=15)
plt.suptitle("Repayment Status for last 6 months with proportion of defaulting payment next month", fontsize=20)

plt.show()

# %% [markdown]
# #### Above plot shows us the proportion of clients that will default payment next month based on repayment history.
# #### For Current month status, the earlier the payment is made lesser are the chances of those clients defaulting the payment.
#
# ### General Trend stats that As people ask for more months they are more likely to not be a defaulter after observing the 6 plots
#
# Most customers are duly paying their credit card bills. And it's pretty clear that their likelihood of default are much lower than the rest.
#
# Since there are only a few customers with 4+ months of delay in all PAY_X features, we could make a new analysis with them all together just to have the average default of a more significant group.

# %%
## We have already analyzed the Bill Amounts

# %% [markdown]
# ## Amount of previous payment

# %%
pay_amtx_fts = ['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

# %%
df['PAY_AMT1_bin'] = df['PAY_AMT1'].copy()
df['PAY_AMT2_bin'] = df['PAY_AMT2'].copy()
df['PAY_AMT3_bin'] = df['PAY_AMT3'].copy()
df['PAY_AMT4_bin'] = df['PAY_AMT4'].copy()
df['PAY_AMT5_bin'] = df['PAY_AMT5'].copy()
df['PAY_AMT6_bin'] = df['PAY_AMT6'].copy()

# %%
pay_amtx_bins = ['PAY_AMT1_bin', 'PAY_AMT2_bin', 'PAY_AMT3_bin', 'PAY_AMT4_bin', 'PAY_AMT5_bin', 'PAY_AMT6_bin']

for i, col in enumerate (pay_amtx_bins):
    df[col] = pd.cut(df[pay_amtx_fts[i]],[-1, 0, 25000, 50000, 100000, 2000000])
    print(df[col].value_counts())
# Out:
# (0, 25000]           23730
# (-1, 0]               5249
# (25000, 50000]         550
# (50000, 100000]        322
# (100000, 2000000]      149
# Name: PAY_AMT1_bin, dtype: int64
# (0, 25000]           23569
# (-1, 0]               5396
# (25000, 50000]         556
# (50000, 100000]        283
# (100000, 2000000]      196
# Name: PAY_AMT2_bin, dtype: int64
# (0, 25000]           23068
# (-1, 0]               5968
# (25000, 50000]         514
# (50000, 100000]        273
# (100000, 2000000]      177
# Name: PAY_AMT3_bin, dtype: int64
# (0, 25000]           22641
# (-1, 0]               6408
# (25000, 50000]         533
# (50000, 100000]        271
# (100000, 2000000]      147
# Name: PAY_AMT4_bin, dtype: int64
# (0, 25000]           22382
# (-1, 0]               6703
# (25000, 50000]         493
# (50000, 100000]        268
# (100000, 2000000]      154
# Name: PAY_AMT5_bin, dtype: int64
# (0, 25000]           21785
# (-1, 0]               7173
# (25000, 50000]         517
# (50000, 100000]        300
# (100000, 2000000]      225
# Name: PAY_AMT6_bin, dtype: int64

# %%
for col in pay_amtx_bins:
    print(df['def_pay'].groupby(df[col]).value_counts(normalize = True))
# Out:
# PAY_AMT1_bin       def_pay
# (-1, 0]            0          0.64
#                    1          0.36
# (0, 25000]         0          0.80
#                    1          0.20
# (25000, 50000]     0          0.91
#                    1          0.09
# (50000, 100000]    0          0.92
#                    1          0.08
# (100000, 2000000]  0          0.91
#                    1          0.09
# Name: def_pay, dtype: float64
# PAY_AMT2_bin       def_pay
# (-1, 0]            0          0.67
#                    1          0.33
# (0, 25000]         0          0.80
#                    1          0.20
# (25000, 50000]     0          0.93
#                    1          0.07
# (50000, 100000]    0          0.94
#                    1          0.06
# (100000, 2000000]  0          0.91
#                    1          0.09
# Name: def_pay, dtype: float64
# PAY_AMT3_bin       def_pay
# (-1, 0]            0          0.68
#                    1          0.32
# (0, 25000]         0          0.80
#                    1          0.20
# (25000, 50000]     0          0.89
#                    1          0.11
# (50000, 100000]    0          0.93
#                    1          0.07
# (100000, 2000000]  0          0.87
#                    1          0.13
# Name: def_pay, dtype: float64
# PAY_AMT4_bin       def_pay
# (-1, 0]            0          0.69
#                    1          0.31
# (0, 25000]         0          0.80
#                    1          0.20
# (25000, 50000]     0          0.90
#                    1          0.10
# (50000, 100000]    0          0.87
#                    1          0.13
# (100000, 2000000]  0          0.90
#                    1          0.10
# Name: def_pay, dtype: float64
# PAY_AMT5_bin       def_pay
# (-1, 0]            0          0.71
#                    1          0.29
# (0, 25000]         0          0.80
#                    1          0.20
# (25000, 50000]     0          0.88
#                    1          0.12
# (50000, 100000]    0          0.90
#                    1          0.10
# (100000, 2000000]  0          0.87
#                    1          0.13
# Name: def_pay, dtype: float64
# PAY_AMT6_bin       def_pay
# (-1, 0]            0          0.71
#                    1          0.29
# (0, 25000]         0          0.80
#                    1          0.20
# (25000, 50000]     0          0.87
#                    1          0.13
# (50000, 100000]    0          0.88
#                    1          0.12
# (100000, 2000000]  0          0.88
#                    1          0.12
# Name: def_pay, dtype: float64

# %%
plt.figure(figsize=(20,15))

for i,col in enumerate(pay_amtx_bins):    
    plt.subplot(3,2,i + 1)
    ax = sns.countplot(data = df, x = col, hue="def_pay")
    plt.xticks( rotation='45')
    plt.ylim(0,23000)
    plt.ylabel('')
    plt.tight_layout()
    
    for p in ax.patches:
        ax.annotate((p.get_height()), (p.get_x()+0.05, p.get_height()+800), fontsize=10)    

plt.show()

# %%
plt.figure(figsize=(15,12))

for i,col in enumerate(pay_amtx_bins):    
    plt.subplot(3,2,i + 1)
    ax = sns.barplot(x = col, y = "def_pay", data = df, palette = 'rocket', ci = None)
    plt.ylabel("% of Default", fontsize= 12)
    plt.xticks( rotation='45')
    plt.ylim(0,0.5)
    plt.tight_layout()
    
    for p in ax.patches:
        ax.annotate("%.2f" %(p.get_height()), (p.get_x()+0.25, p.get_height()+0.03),fontsize=13)

plt.show()

# %%
sns.jointplot(x='LIMIT_BAL', y ='bill_total', data = df, hue = 'def_pay', kind = 'scatter')

# %%
## general trends in Bill Amount (Outstanding Amount ) And Max_outstanding amout(Limit Credit)

# %%
fig = px.box(df, x='LIMIT_BAL', notched= True, points= 'all')
fig.show()
fig = px.box(df, x='bill_total', notched= True, points= 'all')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="810e0679-6fa3-4b88-9d79-86c338b17ce0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("810e0679-6fa3-4b88-9d79-86c338b17ce0")) {                    Plotly.newPlot(                        "810e0679-6fa3-4b88-9d79-86c338b17ce0",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"LIMIT_BAL=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":true,"offsetgroup":"","orientation":"h","showlegend":false,"x":[20000,120000,90000,50000,50000,50000,500000,100000,140000,20000,200000,260000,630000,70000,250000,50000,20000,320000,360000,180000,130000,120000,70000,450000,90000,50000,60000,50000,50000,50000,230000,50000,100000,500000,500000,160000,280000,60000,50000,280000,360000,70000,10000,140000,40000,210000,20000,150000,380000,20000,70000,100000,310000,180000,150000,500000,180000,180000,200000,400000,500000,70000,50000,50000,130000,200000,10000,210000,130000,20000,80000,320000,200000,290000,340000,20000,50000,300000,30000,240000,470000,360000,60000,400000,50000,160000,360000,160000,130000,20000,200000,280000,100000,160000,60000,90000,360000,150000,50000,20000,140000,380000,480000,50000,60000,70000,80000,350000,130000,360000,330000,50000,280000,100000,50000,30000,240000,80000,400000,240000,50000,450000,110000,310000,20000,20000,200000,180000,50000,60000,30000,240000,420000,330000,30000,240000,150000,210000,50000,50000,240000,180000,50000,170000,20000,50000,170000,200000,80000,260000,140000,80000,350000,280000,30000,140000,200000,200000,210000,50000,30000,50000,290000,250000,60000,110000,370000,100000,90000,50000,270000,300000,50000,50000,360000,130000,80000,50000,20000,80000,240000,80000,500000,60000,20000,100000,360000,200000,130000,20000,310000,60000,180000,180000,50000,50000,150000,20000,500000,30000,180000,140000,140000,120000,360000,20000,100000,210000,80000,330000,220000,210000,40000,30000,470000,30000,240000,80000,110000,310000,360000,330000,300000,320000,50000,170000,350000,20000,50000,20000,50000,20000,50000,190000,60000,80000,150000,210000,240000,140000,60000,50000,50000,180000,30000,20000,250000,100000,330000,50000,50000,30000,140000,160000,400000,50000,140000,160000,100000,220000,510000,50000,160000,230000,80000,150000,10000,130000,40000,50000,100000,120000,260000,200000,360000,70000,460000,50000,50000,250000,30000,270000,180000,100000,230000,210000,210000,440000,100000,240000,280000,50000,30000,10000,130000,200000,120000,210000,280000,300000,100000,440000,50000,20000,200000,110000,500000,300000,30000,60000,400000,180000,20000,200000,100000,60000,110000,260000,50000,180000,110000,340000,50000,230000,360000,210000,220000,60000,340000,150000,200000,130000,60000,400000,20000,190000,260000,140000,50000,120000,240000,50000,200000,180000,180000,160000,100000,50000,140000,30000,90000,200000,380000,80000,50000,180000,240000,380000,110000,260000,500000,320000,50000,110000,230000,330000,50000,10000,300000,20000,180000,160000,90000,30000,180000,30000,30000,140000,210000,50000,130000,50000,140000,170000,80000,410000,80000,80000,150000,260000,350000,280000,310000,140000,360000,140000,100000,50000,210000,120000,240000,60000,150000,30000,160000,200000,120000,500000,320000,280000,60000,200000,230000,230000,480000,50000,200000,50000,50000,260000,30000,440000,230000,200000,490000,80000,20000,170000,70000,210000,90000,390000,110000,580000,360000,270000,60000,110000,50000,80000,50000,100000,30000,200000,240000,220000,160000,180000,200000,140000,380000,600000,260000,200000,80000,40000,130000,50000,230000,70000,180000,80000,290000,230000,170000,230000,220000,230000,500000,90000,390000,400000,180000,60000,120000,60000,50000,70000,500000,200000,250000,140000,70000,90000,100000,190000,230000,3200 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4daaf196-e225-41b6-bf3a-ec8a2bc4a4d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4daaf196-e225-41b6-bf3a-ec8a2bc4a4d7")) {                    Plotly.newPlot(                        "4daaf196-e225-41b6-bf3a-ec8a2bc4a4d7",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"bill_total=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":true,"offsetgroup":"","orientation":"h","showlegend":false,"x":[7704,17077,101653,231334,109339,238114,2724595,13486,65212,26919,34467,88369,41007,338685,373591,196416,106161,966014,0,0,123883,1896,265475,26965,31864,214295,-394,112268,40208,97082,113746,151869,495237,125744,58318,25312,1069977,32279,780,51643,1650751,392856,22761,385134,147185,0,79328,9837,114815,115810,229012,265185,44125,259151,176751,8388,55404,952362,6747,2284140,109699,244242,157674,57884,2452,469636,22852,8589,7901,88326,2340,362152,26425,5514,142199,101328,145406,1746,149186,0,614823,294903,143566,700952,177499,667013,3510,31623,226534,61309,862167,15360,3555,4162,197839,354716,58460,479411,83794,93217,13679,132602,2761015,205366,342038,32109,17865,10987,680938,-618,639580,93139,855008,335186,119110,117660,7456,99022,71828,209703,290245,0,0,1626538,112100,0,617685,668882,30548,264125,32776,11279,1349911,1369317,123482,77708,140829,43256,6932,208330,0,3828,99487,67988,26510,48184,105012,794273,61950,21038,411323,256528,4744,971621,70072,222980,575407,1018160,805451,79884,162596,3396,3637,918942,150304,539339,63070,310089,472951,171359,180209,11780,53787,-11569,77,410575,15624,220483,83914,323559,118261,129487,579243,222443,50904,92351,163546,1182582,57742,125792,353740,130018,45854,68239,84870,228759,1616,103511,6457,117854,750,130872,64236,688894,1202779,98941,3033,9657,391407,19462,419979,2384,215945,103603,2002818,3510,-5676,470809,453847,6092,685565,2005418,1431315,437268,243968,772102,8384,108461,202501,63912,132930,94656,197548,828058,175794,41852,399780,18130,1313227,115854,44436,241244,169234,14634,613,79889,63417,196498,256005,117871,240862,135160,631439,337391,34030,173552,27095,82207,62170,1129440,513211,202201,63277,53735,35054,7104,52136,357781,207975,73717,180209,4414,0,80871,0,265753,28039,2736,211791,604011,6448,486594,760211,323182,667517,211039,358970,828179,403638,56097,-336259,0,12972,56848,0,978958,7765,858448,273640,45400,462851,0,154301,98447,18236,12860,47529,5215,72863,65912,21153,827666,79047,333047,194503,171532,303817,2025,213516,-12,311346,923137,31650,55327,575409,160699,3375,170082,137566,624055,47390,66514,96266,79988,116747,912875,953100,390,234080,16986,368,18847,76669,920802,734847,9832,19223,273459,839924,117890,86582,-26795,0,303152,109216,177278,724940,1082561,487656,137687,2926653,436318,248859,4498,3314,15640,218302,14752,0,93331,83538,61480,253776,141140,836186,126272,132258,45024,327465,83951,472379,16397,538393,29372,107251,1741454,80000,416184,944099,2586,0,174954,503434,118369,63000,858345,240783,1480,567259,703798,666907,185007,7098,161543,974815,92108,47869,2466458,365115,1043732,185629,257,11600,64332,292489,27500,23286,104694,180417,0,166661,962256,17733,613953,1185021,11262,79043,1393,293401,762633,465009,1772871,304292,994160,36696,1359821,14672,367490,235192,339098,28024,531060,4137,730818,1306045,160668,601165,83747,170347,461266,0,2718542,935929,162165,331586,124960,439958,99206,48732,156587,838496,28137,248603,564897,2141,1210604,1188181,142857,300881,19471,1864430,1618141,11563,192042,19210,167658,195918,380598,2751,0,274820,832487,169724,411870,10198,894199,52633,556223,4024,37990,573,144207,668040,46228,58976,2336,1196650,123892,1819,114642,138451,162740,1249171,107017,0,3200,761573,226042,75825,11330,651 ...

# %% [markdown]
# The analysis shows that  There is a higher default rate among those who paid nothing in previous months and lower rates among those paid over 25k of NT dollars.

# %%
## data are distributed in a wide range (below), need to be normalizded.
plt.figure(figsize=(15,3))
ax= df.drop('def_pay', axis=1).boxplot(df.columns.name, rot=90)
outliers = dict(markerfacecolor='b', marker='p')
#ax= features.boxplot(features.columns.name, rot=90, flierprops=outliers)
plt.xticks(size=12)
ax.set_ylim([-5000,100000])
plt.box(False);

# %% [markdown]
# #### Hence they need to standerdized
# The boxplot below reveals that features are in different scales and units.

# %% [markdown]
# ### Till Now we have done with Univarient and bivarient analysis Now looking at the corelation will give us a faire say On Features

# %%
#  looking at correlations matrix, defined via Pearson function  
corr = df.corr() # .corr is used to find corelation


plt.figure(figsize = (20,9))
sns.heatmap(corr,vmax=1, annot=True, annot_kws={"size":7})

# %% [markdown]
# ### Summary
# #### Overall, the offered credit limit seems to match the ability to pay in time within each category.
# #### The exceptions are the unknown categories, which have lower chances of default, but do not lead in the amount of given credit
# #### The age group of 60+, which, despite having one of the highest chances of default, receives, on average, the highest credit value.by age group.
# #### The analysis shows that There is a higher default rate among those who paid nothing in previous months and lower rates among those paid over 25k of NT dollars.
# ####
# #### Higher the Limit Amount lesser are the chances of being a Defaulter And same goes with Our Total bill amount
# #### Analyzing the trends with age, education , marrige , credit limit
# #### Credit limit is the most important factor followed by the age
# #### The order of importance of other feature is as followed  Education , Sex ,Marrige
# ### With Bivarient analysis and Correlation also we can say that History of past payment(PAY_N) Out of which also September plays a mojor role in our analysis as it gives the clear plcture of Dealay in the months for payment

# %%
#preprocessing the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30000 entries, 0 to 29999
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     30000 non-null  int64
#  1   LIMIT_BAL              30000 non-null  int64
#  2   SEX                    30000 non-null  int64
#  3   EDUCATION              30000 non-null  int64
#  4   MARRIAGE               30000 non-null  int64
#  5   AGE                    30000 non-null  int64
#  6   PAY_1                  30000 non-null  int64
#  7   PAY_2                  30000 non-null  int64
#  8   PAY_3                  30000 non-null  int64
#  9   PAY_4                  30000 non-null  int64
#  10  PAY_5                  30000 non-null  int64
#  11  PAY_6                  30000 non-null  int64
#  12  BILL_AMT1              30000 non-null  int64
#  13  BILL_AMT2              30000 non-null  int64
#  14  BILL_AMT3              30000 non-null  int64
#  15  BILL_AMT4              30000 non-null  int64
#  16  BILL_AMT5              30000 non-null  int64
#  17  BILL_AMT6              30000 non-null  int64
#  18  PAY_AMT1               30000 non-null  int64
#  19  PAY_AMT2               30000 non-null  int64
#  20  PAY_AMT3               30000 non-null  int64
#  21  PAY_AMT4               30000 non-null  int64
#  22  PAY_AMT5               30000 non-null  int64
#  23  PAY_AMT6               30000 non-null  int64
#  24  def_pay                30000 non-null  int64
#  25  bill_total             30000 non-null  int64
#  26  pay_amt_total          30000 non-null  int64
#  27  remaining_pay_balance  30000 non-null  int64
#  28  LimitBin               30000 non-null  object
#  29  LimitBin_A             30000 non-null  object
#  30  AgeBin                 30000 non-null  object
#  31  PAY_AMT1_bin           30000 non-null  category
#  32  PAY_AMT2_bin           30000 non-null  category
#  33  PAY_AMT3_bin           30000 non-null  category
#  34  PAY_AMT4_bin           30000 non-null  category
#  35  PAY_AMT5_bin           30000 non-null  category
#  36  PAY_AMT6_bin           30000 non-null  category
# dtypes: category(6), int64(28), object(3)
# memory usage: 7.5+ MB

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2', 'PAY_3',
#        'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5',
#        'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
#  13  BILL_AMT2                   30000 non-null  int64
#  14  BILL_AMT3                   30000 non-null  int64
#  15  BILL_AMT4                   30000 non-null  int64
#  16  BILL_AMT5                   30000 non-null  int64
#  17  BILL_AMT6                   30000 non-null  int64
#  18  PAY_AMT1                    30000 non-null  int64
#  19  PAY_AMT2                    30000 non-null  int64
#  20  PAY_AMT3                    30000 non-null  int64
#  21  PAY_AMT4                    30000 non-null  int64
#  22  PAY_AMT5                    30000 non-null  int64
#  23  PAY_AMT6                    30000 non-null  int64
#  24  default payment next month  30000 non-null  int64
# dtypes: int64(25)
# memory usage: 5.7 MB

# %%
df.shape
# Out:
# (30000, 37)

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix, classification_report, f1_score, precision_score, recall_score, roc_auc_score, roc_curve


from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import accuracy_score,recall_score

from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score, GridSearchCV

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.filterwarnings("ignore", category=FutureWarning) 
warnings.filterwarnings("ignore", category=UserWarning) 

# %config InlineBackend.figure_format = 'retina'

# %%
features=df.drop('default payment next month',axis=1)
labele=df["default payment next month"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, labele, test_size=0.33,random_state=42 )

# %%
# Models for Classification
models = [('CART', DecisionTreeClassifier(random_state=123456)),
          ('RF', RandomForestClassifier(random_state=123456))]
results = []
names = []
for name, model in models:
    kfold = KFold(n_splits=10)
    cv_results = cross_val_score(model,features, labele, cv=kfold)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# CART: 0.715567 (0.036843)
# RF: 0.818500 (0.014346)

# %%
# GB Confusion Matrix
model_RF = RandomForestClassifier()
model_RF.fit(X_train, y_train)
y_pred = model_RF.predict(X_test)
conf_mat = confusion_matrix(y_pred,y_test)
conf_mat
# Out:
# array([[7292, 1374],
#        [ 450,  784]])
